# %% [markdown]
# # Bert Text Classification

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("company_desc_translated.csv", sep=";")
df
# Out:
#                              company_name score  \
# 0                              Le Fourgon   4,9
# 1                     Comptoir des Vignes   4,9
# 2                              Shin Sekai   4,9
# 3                           Nutri Naturel   4,9
# 4      Maison Martin - Le Piment Français   4,9
# ...                                   ...   ...
# 12991                        Ljbautoparts   1,2
# 12992                  Aéroports de Paris   1,2
# 12993                          Online SAS   1,7
# 12994                      shopequitation   1,2
# 12995                    Odyssee Transfer   1,1
#
#                                              description  description_len  \
# 0      Le Fourgon vous livre vos boissons consignees ...              342
# 1      Comptoir des Vignes est une enseigne de caves ...              877
# 2      Bienvenue sur notre page Trustpilot ! Shin Sek...              391
# 3      Nutri-Naturel.com, l'epicerie bio en ligne de ...              587
# ...

# %%
df[["company_name", "description_en", "category"]]
# Out:
#                              company_name  \
# 0                              Le Fourgon
# 1                     Comptoir des Vignes
# 2                              Shin Sekai
# 3                           Nutri Naturel
# 4      Maison Martin - Le Piment Français
# ...                                   ...
# 12991                        Ljbautoparts
# 12992                  Aéroports de Paris
# 12993                          Online SAS
# 12994                      shopequitation
# 12995                    Odyssee Transfer
#
#                                           description_en  \
# 0      Le Fourgon delivers your stored drinks to your...
# 1      Comptoir des Vignes is a brand of cellars spec...
# 2      Welcome to our Trustpilot page! Shin Sekai is ...
# 3      Nutri-Naturel.com, the leading online organic ...
# 4      Maison Martin - Le Piment Francais is the firs...
# ...                                                  ...
# ...

# %%
category_count = df["category"].value_counts().reset_index()
category_count
# Out:
#                          index  category
# 0       electronics_technology      1335
# 1                  home_garden      1258
# 2             shopping_fashion      1236
# 3              money_insurance      1180
# 4         events_entertainment       931
# 5             beauty_wellbeing       854
# 6       food_beverages_tobacco       810
# 7   construction_manufactoring       777
# 8            business_services       768
# 9      vehicles_transportation       740
# 10          education_training       703
# 11             travel_vacation       464
# 12              hobbies_crafts       450
# 13            media_publishing       351
# 14                      sports       233
# 15                animals_pets       232
# 16              health_medical       155
# 17               home_services       155
# 18   legal_services_government       147
# 19       public_local_services       121
# 20            restaurants_bars        86
# 21                   utilities        10

# %%
fig = px.bar(category_count, x="index", y="category", title="Number of Companies per Category")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### There is a class imbalance we need to resample the data

# %%
category_list = list(category_count[category_count["category"] >= 450]["index"])
category_list
# Out:
# ['electronics_technology',
#  'home_garden',
#  'shopping_fashion',
#  'money_insurance',
#  'events_entertainment',
#  'beauty_wellbeing',
#  'food_beverages_tobacco',
#  'construction_manufactoring',
#  'business_services',
#  'vehicles_transportation',
#  'education_training',
#  'travel_vacation',
#  'hobbies_crafts']

# %%
company_sample = df[df["category"].isin(category_list)].dropna()
company_sample["category"].value_counts().reset_index()
# Out:
#                          index  category
# 0       electronics_technology      1183
# 1                  home_garden      1108
# 2             shopping_fashion      1065
# 3              money_insurance      1034
# 4         events_entertainment       766
# 5             beauty_wellbeing       755
# 6       food_beverages_tobacco       740
# 7   construction_manufactoring       709
# 8            business_services       683
# 9           education_training       656
# 10     vehicles_transportation       616
# 11              hobbies_crafts       416
# 12             travel_vacation       407

# %%
company_sample = company_sample.groupby('category').apply(lambda x: x.sample(n=407, random_state=42)).reset_index(drop=True)
company_sample
# Out:
#                company_name score  \
# 0     Oscilance Sophrologie   4,7
# 1           Lesentiergeobio   4,0
# 2          Salvia Nutrition   4,7
# 3                   Mahasoa   4,6
# 4                  Cannibia   4,1
# ...                     ...   ...
# 5286         shopequitation   1,2
# 5287            Puissance12   2,7
# 5288     Automobileoccasion   1,5
# 5289                 Stiilt   4,9
# 5290        TAXI MOTO PARIS   3,8
#
#                                             description  description_len  \
# 0     Developpez votre bien etre avec la sophrologie...              242
# 1     Bienvenue dans ma petite boutique ecologique q...              476
# 2     Expert en aromatherapie Huiles essentielles et...              450
# 3     Achetez en ligne les produits de votre coiffeu...              164
# 4     Pour respecter notre engagement, l'efficacite,...              744
# ...                                                 ...              ...
# ...

# %%
company_sample[["company_name", "description_en", "category"]]
# Out:
#                company_name  \
# 0     Oscilance Sophrologie
# 1           Lesentiergeobio
# 2          Salvia Nutrition
# 3                   Mahasoa
# 4                  Cannibia
# ...                     ...
# 5286         shopequitation
# 5287            Puissance12
# 5288     Automobileoccasion
# 5289                 Stiilt
# 5290        TAXI MOTO PARIS
#
#                                          description_en  \
# 0     Develop your well-being with sophrology Diplom...
# 1     Welcome to my little ecological store which is...
# 2     Expert in aromatherapy Essential oils and cosm...
# 3     Buy your hairdresser's products online thanks ...
# 4     To respect our commitment, the efficiency, saf...
# ...                                                 ...
# 5286  Online specialist in the sale of horse riding ...
# 5287  Browse our store to find the children's car th...
# 5288  Used automobile is a used car sales ad site, p...
# ...

# %%
import torch
from tqdm.notebook import tqdm
import numpy as np

# %%
from transformers import BertTokenizer
from torch.utils.data import TensorDataset

from transformers import BertForSequenceClassification

# %%
company_sample
# Out:
#                company_name score  \
# 0     Oscilance Sophrologie   4,7
# 1           Lesentiergeobio   4,0
# 2          Salvia Nutrition   4,7
# 3                   Mahasoa   4,6
# 4                  Cannibia   4,1
# ...                     ...   ...
# 5286         shopequitation   1,2
# 5287            Puissance12   2,7
# 5288     Automobileoccasion   1,5
# 5289                 Stiilt   4,9
# 5290        TAXI MOTO PARIS   3,8
#
#                                             description  description_len  \
# 0     Developpez votre bien etre avec la sophrologie...              242
# 1     Bienvenue dans ma petite boutique ecologique q...              476
# 2     Expert en aromatherapie Huiles essentielles et...              450
# 3     Achetez en ligne les produits de votre coiffeu...              164
# 4     Pour respecter notre engagement, l'efficacite,...              744
# ...                                                 ...              ...
# ...

# %% [markdown]
# ### Label Encoding

# %%
possible_labels = company_sample.category.unique()

label_dict = {}
for index, possible_label in enumerate(possible_labels):
    label_dict[possible_label] = index
label_dict
# Out:
# {'beauty_wellbeing': 0,
#  'business_services': 1,
#  'construction_manufactoring': 2,
#  'education_training': 3,
#  'electronics_technology': 4,
#  'events_entertainment': 5,
#  'food_beverages_tobacco': 6,
#  'hobbies_crafts': 7,
#  'home_garden': 8,
#  'money_insurance': 9,
#  'shopping_fashion': 10,
#  'travel_vacation': 11,
#  'vehicles_transportation': 12}

# %%
company_sample['label'] = company_sample.category.replace(label_dict)

# %%
company_sample
# Out:
#                company_name score  \
# 0     Oscilance Sophrologie   4,7
# 1           Lesentiergeobio   4,0
# 2          Salvia Nutrition   4,7
# 3                   Mahasoa   4,6
# 4                  Cannibia   4,1
# ...                     ...   ...
# 5286         shopequitation   1,2
# 5287            Puissance12   2,7
# 5288     Automobileoccasion   1,5
# 5289                 Stiilt   4,9
# 5290        TAXI MOTO PARIS   3,8
#
#                                             description  description_len  \
# 0     Developpez votre bien etre avec la sophrologie...              242
# 1     Bienvenue dans ma petite boutique ecologique q...              476
# 2     Expert en aromatherapie Huiles essentielles et...              450
# 3     Achetez en ligne les produits de votre coiffeu...              164
# 4     Pour respecter notre engagement, l'efficacite,...              744
# ...                                                 ...              ...
# ...

# %%
company_df = company_sample[['category', 'description_en', 'label']]

# %%
company_df
# Out:
#                      category  \
# 0            beauty_wellbeing
# 1            beauty_wellbeing
# 2            beauty_wellbeing
# 3            beauty_wellbeing
# 4            beauty_wellbeing
# ...                       ...
# 5286  vehicles_transportation
# 5287  vehicles_transportation
# 5288  vehicles_transportation
# 5289  vehicles_transportation
# 5290  vehicles_transportation
#
#                                          description_en  label
# 0     Develop your well-being with sophrology Diplom...      0
# 1     Welcome to my little ecological store which is...      0
# 2     Expert in aromatherapy Essential oils and cosm...      0
# 3     Buy your hairdresser's products online thanks ...      0
# 4     To respect our commitment, the efficiency, saf...      0
# ...                                                 ...    ...
# 5286  Online specialist in the sale of horse riding ...     12
# 5287  Browse our store to find the children's car th...     12
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(company_df.index.values,
                                                  company_df.label.values,
                                                  test_size=0.15,
                                                  random_state=42,
                                                  stratify=company_df.label.values)

company_df['data_type'] = ['not_set']*company_df.shape[0]

company_df.loc[X_train, 'data_type'] = 'train'
company_df.loc[X_val, 'data_type'] = 'val'

company_df.groupby(['category', 'label', 'data_type']).count()
# Out:
# <ipython-input-75-baccca37015f>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                             description_en
# category                   label data_type
# beauty_wellbeing           0     train                 346
#                                  val                    61
# business_services          1     train                 346
#                                  val                    61
# construction_manufactoring 2     train                 346
#                                  val                    61
# education_training         3     train                 346
#                                  val                    61
# electronics_technology     4     train                 346
# ...

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased',
                                          do_lower_case=True)

encoded_data_train = tokenizer.batch_encode_plus(
    company_df[company_df.data_type=='train'].description_en.values,
    add_special_tokens=True,
    return_attention_mask=True,
    pad_to_max_length=True,
    max_length=256,
    return_tensors='pt'
)

encoded_data_val = tokenizer.batch_encode_plus(
    company_df[company_df.data_type=='val'].description_en.values,
    add_special_tokens=True,
    return_attention_mask=True,
    pad_to_max_length=True,
    max_length=256,
    return_tensors='pt'
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(company_df[company_df.data_type=='train'].label.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
labels_val = torch.tensor(company_df[company_df.data_type=='val'].label.values)

dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, labels_val)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2614: FutureWarning:
#
# The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

batch_size = 3

dataloader_train = DataLoader(dataset_train,
                              sampler=RandomSampler(dataset_train),
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_val,
                                   sampler=SequentialSampler(dataset_val),
                                   batch_size=batch_size)

# %%
from transformers import AdamW, get_linear_schedule_with_warmup

optimizer = AdamW(model.parameters(),
                  lr=1e-5,
                  eps=1e-8)

epochs = 2

scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning:
#
# This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning

# %% [markdown]
# ## Metrics

# %%
from sklearn.metrics import f1_score

def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in label_dict.items()}

    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(device)
# Out:
# cpu

# %%
import random

# %%
seed_val = 17
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

def evaluate(dataloader_val):

    model.eval()

    loss_val_total = 0
    predictions, true_vals = [], []

    for batch in dataloader_val:

        batch = tuple(b.to(device) for b in batch)

        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():
            outputs = model(**inputs)

        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)

    loss_val_avg = loss_val_total/len(dataloader_val)

    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)

    return loss_val_avg, predictions, true_vals

# %%
for epoch in tqdm(range(1, epochs+1)):

    model.train()

    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()

        batch = tuple(b.to(device) for b in batch)

        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        outputs = model(**inputs)

        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()

        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})


    torch.save(model.state_dict(), f'finetuned_BERT_epoch_{epoch}.model')

    tqdm.write(f'\nEpoch {epoch}')

    loss_train_avg = loss_train_total/len(dataloader_train)
    tqdm.write(f'Training loss: {loss_train_avg}')

    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    val_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {val_loss}')
    tqdm.write(f'F1 Score (Weighted): {val_f1}')
# Out:
# ...
# Epoch 1:   0%|          | 0/1499 [00:00<?, ?it/s]
# Epoch 1
# Training loss: 0.8956769678152705
# Validation loss: 1.2226466791528576
# F1 Score (Weighted): 0.6734839656117104

# %% [markdown]
# ## Evaluate Model

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)

model.to(device)

model.load_state_dict(torch.load('finetuned_BERT_epoch_1.model', map_location=torch.device('cpu')))

_, predictions, true_vals = evaluate(dataloader_validation)
accuracy_per_class(predictions, true_vals)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Class: beauty_wellbeing
# Accuracy: 51/61
#
# Class: business_services
# Accuracy: 29/61
#
# Class: construction_manufactoring
# Accuracy: 30/61
#
# Class: education_training
# Accuracy: 51/61
#
# Class: electronics_technology
# Accuracy: 32/61
#
# Class: events_entertainment
# Accuracy: 29/61
#
# Class: food_beverages_tobacco
# Accuracy: 52/62
#
# Class: hobbies_crafts
# Accuracy: 39/61
#
# Class: home_garden
# Accuracy: 32/61
#
# Class: money_insurance
# Accuracy: 47/61
#
# Class: shopping_fashion
# Accuracy: 45/61
#
# Class: travel_vacation
# Accuracy: 49/61
#
# Class: vehicles_transportation
# Accuracy: 52/61
